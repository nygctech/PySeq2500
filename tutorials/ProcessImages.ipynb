# %%
from pyseq import image_analysis as ia
import logging
LOGGER  = logging.getLogger()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-c05156ab7f44> in <module>
# ----> 1 from pyseq import image_analysis as ia
#       2 import logging
#       3 LOGGER  = logging.getLogger()
#
# c:\users\public\documents\pyseq2500\pyseq2500v2\pyseq\__init__.py in <module>
#      63 from . import ystage
#      64 from . import zstage
# ---> 65 from . import focus
#      66 from . import temperature
#      67 from .image_analysis import get_machine_config
#
# c:\users\public\documents\pyseq2500\pyseq2500v2\pyseq\focus.py in <module>
#       5 from os import name as os_name
#       6 from math import log2, ceil
# ----> 7 from . import image_analysis as IA
#       8 from scipy import stats
#       9 from scipy.optimize import least_squares
#
# c:\users\public\documents\pyseq2500\pyseq2500v2\pyseq\image_analysis.py in <module>
#      21 import yaml
# ...

# %%
image_path = "C:\\Users\\pysequser\\tetraspeck_20260518"
image = ia.get_HiSeqImages(image_path, logger=LOGGER)

# %%
image.im

# %%
image.correct_background()
image.register_channels_affine()
